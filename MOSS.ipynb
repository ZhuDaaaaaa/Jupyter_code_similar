# %%
import mosspy
help(mosspy)
import numpy as np
# Out:
# Help on package mosspy:
#
# NAME
#     mosspy
#
# PACKAGE CONTENTS
#     download_report
#     moss
#
# VERSION
#     1.0.8
#
# FILE
#     f:\anaconda\lib\site-packages\mosspy\__init__.py

# %%
import mosspy

userid = 604014254

m = mosspy.Moss(userid, "python")

m.addBaseFile("./original/Assignment 1/Assignment 1.ipynb")
# m.addBaseFile("submission/test_student.py")

# Submission Files
# m.addFile("submission/a01-sample.py")
m.addFilesByWildcard("./data/Assignment 1/last/*.ipynb")

url = m.send() # Submission Report URL

print ("Report Url: " + url)

# Save report file
m.saveWebPage(url, "./result/Assignment 1/report.html")

# Download whole report locally including code diff links
mosspy.download_report(url, "./result/Assignment 1/", connections=8)
# Out:
# Report Url: http://moss.stanford.edu/results/7/1362089422504
# DEBUG:root:================================================================================
# DEBUG:root:Downloading Moss Report - URL: http://moss.stanford.edu/results/7/1362089422504
# DEBUG:root:================================================================================
# DEBUG:root:Processing URL: http://moss.stanford.edu/results/7/1362089422504
# DEBUG:root:Processing URL: http://moss.stanford.edu/results/7/1362089422504/match0.html
# DEBUG:root:Processing URL: http://moss.stanford.edu/results/7/1362089422504/match1.html
# DEBUG:root:Processing URL: http://moss.stanford.edu/results/7/1362089422504/match2.html
# DEBUG:root:Processing URL: http://moss.stanford.edu/results/7/1362089422504/match3.html
# DEBUG:root:Processing URL: http://moss.stanford.edu/results/7/1362089422504/match4.html
# DEBUG:root:Processing URL: http://moss.stanford.edu/results/7/1362089422504/match5.html
# ...

# %%
# Out:
# None
